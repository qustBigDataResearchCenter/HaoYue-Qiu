# %%
fname=input('Enter the file name:')
try:
    fhand=open(fname)
except:
    print('File can not be opened:',fname)
    quit()
    
count=0
for line in fhand:
    if line.startswith('Subject:'):
        count=count+1
print('There were',count,'subject lines in',fname)
# Out:
# Enter the file name:mbox.txt
# There were 27 subject lines in mbox.txt

# %%
fname=input('Enter the file name:')
try:
    fhand=open(fname)
except:
    print('File can not be opened:',fname)
    quit()
    
count=0
for line in fhand:
    if line.startswith('Subject:'):
        count=count+1
print('There were',count,'subject lines in',fname)
# Out:
# Enter the file name:lalala
# File can not be opened: lalala
# There were 0 subject lines in lalala

# %%
fh=open('mbox-short.txt')
#print(fh)

# %%
for lx in fh:
    ly=lx.rstrip()
    print(ly.upper())         #先打开再读取
# Out:
# FROM STEPHEN.MARQUARD@UCT.AC.ZA SAT JAN  5 09:14:16 2008
# RETURN-PATH: <POSTMASTER@COLLAB.SAKAIPROJECT.ORG>
# RECEIVED: FROM MURDER (MAIL.UMICH.EDU [141.211.14.90])
# 	 BY FRANKENSTEIN.MAIL.UMICH.EDU (CYRUS V2.3.8) WITH LMTPA;
# 	 SAT, 05 JAN 2008 09:14:16 -0500
# X-SIEVE: CMU SIEVE 2.3
# RECEIVED: FROM MURDER ([UNIX SOCKET])
# 	 BY MAIL.UMICH.EDU (CYRUS V2.2.12) WITH LMTPA;
# 	 SAT, 05 JAN 2008 09:14:16 -0500
# RECEIVED: FROM HOLES.MR.ITD.UMICH.EDU (HOLES.MR.ITD.UMICH.EDU [141.211.14.79])
# 	BY FLAWLESS.MAIL.UMICH.EDU () WITH ESMTP ID M05EEFR1013674;
# 	SAT, 5 JAN 2008 09:14:15 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (APP1.PROD.COLLAB.UHI.AC.UK [194.35.219.184])
# 	BY HOLES.MR.ITD.UMICH.EDU ID 477F90B0.2DB2F.12494 ;
# 	 5 JAN 2008 09:14:10 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (LOCALHOST [127.0.0.1])
# 	BY PAPLOO.UHI.AC.UK (POSTFIX) WITH ESMTP ID 5F919BC2F2;
# 	SAT,  5 JAN 2008 14:10:05 +0000 (GMT)
# MESSAGE-ID: <200801051412.M05ECIAH010327@NAKAMURA.UITS.IUPUI.EDU>
# ...

# %%
for lx in fh:
    print(lx)        #先打开再读取
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# Return-Path: <postmaster@collab.sakaiproject.org>
#
# Received: from murder (mail.umich.edu [141.211.14.90])
#
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
#
# 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# X-Sieve: CMU Sieve 2.3
#
# Received: from murder ([unix socket])
#
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
#
# 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
#
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
#
# 	Sat, 5 Jan 2008 09:14:15 -0500
#
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
#
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
#
# 	 5 Jan 2008 09:14:10 -0500
#
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
#
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
#
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
#
# ...

# %%
print([1,2,3,4])
print(['cwc','wer','qwrf'])
print(['cwrve','wrvqet',23,3223])
print([1,3,4,[34,5],14])
print(len([1,3,4,[34,5],14]))          #这个list中有5个元素1,3,4,14,[34,5]
print([])                               #list元素可以是数字，字符或是list，也可以空
# Out:
# [1, 2, 3, 4]
# ['cwc', 'wer', 'qwrf']
# ['cwrve', 'wrvqet', 23, 3223]
# [1, 3, 4, [34, 5], 14]
# 5
# []

# %%
fruit='Banana'
#fruit[0]='b' mistake，string元素不能改
x=fruit.lower()
print(x)
# Out:
# banana

# %%
lotto=[4,5555,3,22,4,]
print(lotto)
lotto[1]=5
print(lotto)
# Out:
# [4, 5555, 3, 22, 4]
# [4, 5, 3, 22, 4]

# %%
print(range(4))
f=['adf','xewq','EC']
print(len(f))
print(range(len(f)))
# Out:
# range(0, 4)
# 3
# range(0, 3)

# %%
print(range(9))      #python2中range(9)执行结果为[0,1,2,3,4,5,6,7,8]
# Out:
# range(0, 9)

# %%
a=[1,2]
b=[2,4,5]
c=a+b
print(c,c[2:3],c[:],c[3:],c[:4])      #just like in strings,the second number is"up to but not including"
# Out:
# [1, 2, 2, 4, 5] [2] [1, 2, 2, 4, 5] [4, 5] [1, 2, 2, 4]

# %%
total=0
count=0
while True:
    inp=input('Enter a number:')
    if inp=='done':
        break
    total=total+float(inp)          #输入的同时进行一部分计算
    count=count+1
    
print('Average:',total/count)
# Out:
# Enter a number:1
# Enter a number:2
# Enter a number:3
# Enter a number:done
# Average: 2.0

# %%
num=list()
while True:
    inp=input('Enter a number:')
    if inp=='done':
        break                        
    num.append(float(inp))                      #只输入不计算
    
print('Average:',sum(num)/len(num))
# Out:
# Enter a number:1
# Enter a number:2
# Enter a number:3
# Enter a number:done
# Average: 2.0

# %%
a='cefwf wefr yhyhts egtgrs'
b=a.split()      #Split breaks a string into parts and produces a list of strings.
print(b,len(b),b[0])
# Out:
# ['cefwf', 'wefr', 'yhyhts', 'egtgrs'] 4 cefwf

# %%
l1='sas                     wfrw'
print(l1.split())
l2='efqw;wrgg;w35t;qw4f3'
print(l2.split(),len(l2.split()),l2.split(';'))      #l2.split()只找space  l1.split(';')找';'
# Out:
# ['sas', 'wfrw']
# ['efqw;wrgg;w35t;qw4f3'] 1 ['efqw', 'wrgg', 'w35t', 'qw4f3']

# %%
x=list()
type(x)
# Out:
# list

# %%
dir(x)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
s=list()     #same as s=[]
s.append('cre')
s.append(['we','rc'])         #s.append('xew','efwf') mistake
s.append(2)
s.append([12,32])
print(s)
# Out:
# ['cre', ['we', 'rc'], 2, [12, 32]]

# %%
t=[3,53,65,77,97,423,9]
9 in t
# Out:
# True

# %%
99 in t
# Out:
# False

# %%
99 not in t
# Out:
# True

# %%
f=[1,23,4,6]
f.sort()
print(f,f[1])
# Out:
# [1, 4, 6, 23] 4

# %%
nums=[3,5,43,6,85,78,9]
print(len(nums),max(nums),min(nums),sum(nums),sum(nums)/len(nums))
# Out:
# 7 85 3 229 32.714285714285715

# %%
l='Form stephen.marquard@uct.ac.za  Sat Jan  5 09:14:16 2008'
w=l.split()
print(w,len(w))
print(w[1].split('@'))
# Out:
# ['Form', 'stephen.marquard@uct.ac.za', 'Sat', 'Jan', '5', '09:14:16', '2008'] 7
# ['stephen.marquard', 'uct.ac.za']
